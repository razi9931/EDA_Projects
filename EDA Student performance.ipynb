# %%
# import all libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")

# %%
student = "/content/drive/MyDrive/EDA FILES/student prog.csv"
df = pd.read_csv(student)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# there are no null values in the dataset

# %%
# Univariate analysis

df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df["school"].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,5))
sns.countplot( x = "school" , data = df, palette = "viridis")
plt.title(" Dist of School")
plt.xlabel("school")
plt.ylabel("Counts")
plt.show()

# %%
#insights GP has larger no. of students

# %%
sns.histplot(df["age"], bins = 10, kde = True , palette = "salmon")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# most common afe group >> 15-16
#skewed dist

# %%
df["address"].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot( x = "address", data = df, palette = "viridis")
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %%
# There are many students from urban areas

# %%
df["reason"].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
reason_count = df["reason"].value_counts()
plt.pie(reason_count, labels = reason_count.index,startangle = 90, autopct = "%1.1f%%", shadow = True , explode=( 0.1, 0.01,0.1,0.2) )
# Out:
# ([<matplotlib.patches.Wedge at 0x78db8f240710>,
# ...
#  [Text(-1.178130830616837, 0.22805206850647555, 'course'),
#   Text(0.3689635009844561, -1.0468839166504056, 'home'),
#   Text(1.1802834328269018, 0.2166356807969188, 'reputation'),
#   Text(0.4439690723983727, 1.2218393768223912, 'other')],
#  [Text(-0.6872429845264881, 0.13303037329544407, '43.9%'),
#   Text(0.2027637257662326, -0.5753145848258985, '23.0%'),
#   Text(0.688498669149026, 0.1263708137982026, '22.0%'),
#   Text(0.273211736860537, 0.7519011549676251, '11.1%')])

# %%
# Insights
# common reason >> would be course

# %%
 activities_counts = df["activities"].value_counts()
 plt.pie(activities_counts, labels = activities_counts.index,startangle = 90, autopct = "%1.1f%%", shadow = True , explode=( 0.1, 0.01))
# Out:
# ([<matplotlib.patches.Wedge at 0x78db8f268bd0>,
# ...
#  [Text(-1.1987313808341125, -0.05516408798795063, 'no'),
#   Text(1.1088265320490212, 0.051026677573022136, 'yes')],
#  [Text(-0.6992599721532322, -0.03217905132630453, '51.5%'),
#   Text(0.6093551212161287, 0.028041687675264413, '48.5%')])

# %%
# 48.5% are participating

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
 Alc_cons = df["Walc"].value_counts()

# %%
# 45 students have regular weekend alcohol consumption

# %%
plt.pie(Alc_cons, labels = Alc_cons.index,startangle = 90, autopct = "%1.1f%%", shadow = True , explode=( 0.1, 0.01,0.2,0.1,0.01))
# Out:
# ([<matplotlib.patches.Wedge at 0x78db8f626a50>,
# ...
#  [Text(-1.1165424798334749, 0.4396963619673405, '1'),
#   Text(-0.026863053998949397, -1.1096748966836412, '2'),
#   Text(1.2464507701142664, -0.36927019603747147, '3'),
#   Text(0.9068994725035225, 0.7858329000320823, '4'),
#   Text(0.2398836689822832, 1.0837692675821724, '5')],
#  [Text(-0.651316446569527, 0.25648954448094863, '38.1%'),
#   Text(-0.014762579224647864, -0.6098213396189379, '23.1%'),
#   Text(0.7670466277626254, -0.22724319756152087, '18.5%'),
#   Text(0.5290246922937214, 0.4584025250187146, '13.4%'),
#   Text(0.13182796223350696, 0.5955849128154281, '6.9%')])

# %%
D_Alc = df["Dalc"].value_counts()

# %%
plt.pie(D_Alc, labels = D_Alc.index,startangle = 90, autopct = "%1.1f%%", shadow = True , explode=( 0.1, 0.2,0.1,0.2,0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x78db8f682650>,
# ...
#  [Text(-0.9819633726827833, -0.6897448330429548, '1'),
#   Text(1.2628588999222028, 0.30852455151459846, '2'),
#   Text(0.6141965331071534, 1.0309037873240905, '3'),
#   Text(0.3176862819671654, 1.2605853506406772, '5'),
#   Text(0.09863834914568437, 1.1959391606924719, '4')],
#  [Text(-0.5728119673982902, -0.4023511526083903, '69.5%'),
#   Text(0.7771439384136632, 0.18986126247052212, '18.6%'),
#   Text(0.3582813109791728, 0.6013605426057195, '6.6%'),
#   Text(0.19549925044133254, 0.7757448311634936, '2.6%'),
#   Text(0.05753903700164921, 0.6976311770706086, '2.6%')])

# %%
# Insights >>
# 5.2% of students are daily consumption of alcohol

# %%
# Bivariate analysis

plt.figure(figsize = ( 12,6))


plt.subplot(1,2,1)
sns.countplot(x = "Medu", data = df, palette = "Set2")
plt.xlabel(" Mother ed Level")
plt.ylabel("Count")
plt.title("Mother education level dist")


plt.subplot(1,2,2)
sns.countplot(x = "Fedu", data = df, palette = "Set3")
plt.xlabel(" father ed Level")
plt.ylabel("Count")
plt.title("Father education level dist")


plt.show()

# %%
#insights >> mother and father edu

# %%
df["studytime"]
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 644    3
# 645    2
# 646    2
# 647    1
# 648    1
# Name: studytime, Length: 649, dtype: int64

# %%
sns.barplot( x = "studytime" , y = "G3" , data = df, palette = "coolwarm")
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %%
sns.barplot( x = "studytime" , y = "G2" , data = df, palette = "coolwarm")
# Out:
# <Axes: xlabel='studytime', ylabel='G2'>

# %%
sns.barplot( x = "internet" , y = "G3" , data = df, palette = "Set2")
# Out:
# <Axes: xlabel='internet', ylabel='G3'>

# %%
# MultiVariate

sns.barplot( x = "sex", y = 'G3', hue = "address", data = df , palette = "Set2")
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %%
num_features = [feature for feature in df.columns if df[feature].dtype != "object"]

# %%
num_features
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %%
plt.figure(figsize=(18,18))

sns.boxplot(data = df[num_features], palette = "Set2")
plt.show()

# %%
corr = df.corr(numeric_only= True)

# %%
plt.figure(figsize = (12,10))
sns.heatmap(corr,annot = True , cmap = "coolwarm", fmt = ".2f")
plt.show()

# %%
# insights >> strong positive correlation, strong negative correlation

# %%
#Outlier detection

student_grades_df = df.copy()

# %%
student_grades_df = student_grades_df.drop(["G1",'G2','G3'],axis = 1)

# %%
def detect_outliers(columns):
    outlier_indices = []
    for column in columns:
        Q1=student_grades_df[column].quantile(0.25)
        Q3=student_grades_df[column].quantile(0.75)
        IQR = Q3-Q1

        #mask is boolean condition
        mask = (student_grades_df[column] >= (Q1-1.5)*IQR) & (student_grades_df[column] <= (Q1+1.5)*IQR)

        mask = mask.to_numpy() #bool value to numpy array

        #find the indices of values that do not satisfy the mask condition >> that will be outlier
        false_indices = np.argwhere(~mask)
        outlier_indices.append(false_indices)
    return np.unique(np.concatenate(outlier_indices).ravel())

# %%
num_cols = ['age', 'absences']
outlier_indices = detect_outliers(num_cols)

# %%
#data split


student_grades_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df_encoded = student_grades_df.apply(lambda col: LabelEncoder().fit_transform(col) if col.dtype == "object" else col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-fcf9a3658e08> in <cell line: 0>()
# ----> 1 df_encoded = student_grades_df.apply(lambda col: LabelEncoder().fit_transform(col) if col.dtype == "object" else col)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# ...

# %%
df_encode = pd.get_dummies(student_grades_df, drop_first=True)
print(df_encode)
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         0       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 644   19     2     3           1          3         1       5         4
# 645   18     3     1           1          2         0       4         3
# 646   18     1     1           2          2         0       1         1
# 647   17     3     1           2          1         0       2         4
# 648   18     3     2           3          1         0       4         4
#
#      goout  Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  \
# ...

# %%
from enum import auto
def auto_encode(df):
  from sklearn.preprocessing import LabelEncoder

  df_encodeed = df.copy()
  for col in df.select_dtype(including=["object"]).columns:
      df_encodeed[col] = LabelEncoder().fit_transform(df[col])
  return df_encodeed

df_encodeed = auto(df)
print(df_encodeed)
# Out:
# auto(    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df_encodeed.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-aa455b1da3f0> in <cell line: 0>()
# ----> 1 df_encodeed.DataFrame()
#
# AttributeError: 'auto' object has no attribute 'DataFrame'
